# %% [markdown]
# ### Testing car and path animation

# %%
import os
path = os.getcwd()
path += "/Utils"
os.chdir(path)

# %%
# %load_ext autoreload
# %autoreload 2
import matplotlib.pyplot as plt
import networkx as nx
import numpy as np
import random
from gridVisualize_util import grid_network_v1, GridwithAgent, generate_animated_path, create_traversal_path

# %reload_ext autoreload

# %%
col = 6
row = 4

# For viewing directly in the notebook
# %matplotlib notebook
fig_width = 8  # (inch) Adjust this to your preference
fig_height = fig_width * (row/col)  # Maintain aspect ratio
plt.gcf().set_size_inches(fig_width, fig_height)

# %%
# Create grid and path
path = [1, (1,2), 2, (2,3), 3]
G_test, W, C = grid_network_v1(mcols=col, nrows=row)
Grid_test = GridwithAgent(G_test, mcols=col, nrows=row)
print('Edges:',Grid_test.G.edges())
print('Nodes:',Grid_test.G.nodes())
Grid_test.place_on_edge(7,6)
# Grid_test.place_on_edge(10,11,frac=0.8,kind='rdr')
Grid_test.place_on_node(15,kind='rdr')
# Grid_test.visualize()

# %%
path = [(7,6,0.5),(6,12),12,(12,13),(13,14),(14,15),15]
travel_path = create_traversal_path(path)
animated_path = generate_animated_path(travel_path)
print(travel_path)
print()
print(animated_path)
# Out:
# [(7, 6, 0.5), (6, 12, 1.0), 12, (12, 13, 1.0), (13, 14, 1.0), (14, 15, 1.0), 15]
#
# [(7, 6, 0.5), (6, 12, 0.0), (6, 12, 0.04456400944391139), (6, 12, 0.16942958916356993), (6, 12, 0.3498655797196585), (6, 12, 0.5501344202803414), (6, 12, 0.73057041083643), (6, 12, 0.8554359905560885), (6, 12, 0.9), 12, (12, 13, 0.0), (12, 13, 0.04456400944391139), (12, 13, 0.16942958916356993), (12, 13, 0.3498655797196585), (12, 13, 0.5501344202803414), (12, 13, 0.73057041083643), (12, 13, 0.8554359905560885), (12, 13, 0.9), (13, 14, 0.0), (13, 14, 0.04456400944391139), (13, 14, 0.16942958916356993), (13, 14, 0.3498655797196585), (13, 14, 0.5501344202803414), (13, 14, 0.73057041083643), (13, 14, 0.8554359905560885), (13, 14, 0.9), (14, 15, 0.0), (14, 15, 0.04456400944391139), (14, 15, 0.16942958916356993), (14, 15, 0.3498655797196585), (14, 15, 0.5501344202803414), (14, 15, 0.73057041083643), (14, 15, 0.8554359905560885), (14, 15, 0.9), 15]

# %%
ani = Grid_test.visualize_animation(
    animated_path, show_path=True, path_color='r',
    show_attribute='weight', save_path='../Anim/test2.gif'
)

ani
# Out:
# <img src="data:image/png;base64,..." width="800">
